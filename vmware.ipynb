# %%
import requests
import json
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
import requests
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '8595939517',
#   'type': 'CreateEvent',
#   'actor': {'id': 17042885,
#    'login': 'nvlsianpu',
#    'display_login': 'nvlsianpu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nvlsianpu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17042885?'},
#   'repo': {'id': 91662498,
#    'name': 'nvlsianpu/zephyr',
#    'url': 'https://api.github.com/repos/nvlsianpu/zephyr'},
#   'payload': {'ref': 'nrf_uicr_support',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Primary GIT Repository for the Zephyr Project',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939508',
#   'type': 'PushEvent',
#   'actor': {'id': 4919946,
#    'login': 'munish-dhiman',
#    'display_login': 'munish-dhiman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/munish-dhiman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4919946?'},
#   'repo': {'id': 128924306,
#    'name': 'munish-dhiman/demo-oauth',
#    'url': 'https://api.github.com/repos/munish-dhiman/demo-oauth'},
#   'payload': {'push_id': 3052488087,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9f838495aab91b632702ba5135421ef69226df03',
#    'before': 'fa08b4924e1b56540d2543db25fba6cf88f0b5cc',
#    'commits': [{'sha': '9f838495aab91b632702ba5135421ef69226df03',
#      'author': {'email': 'munishdhiman84@gmail.com', 'name': 'Munish Dhiman'},
#      'message': 'use of var',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/munish-dhiman/demo-oauth/commits/9f838495aab91b632702ba5135421ef69226df03'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939502',
#   'type': 'ForkEvent',
#   'actor': {'id': 5302702,
#    'login': 'thomaswinckell',
#    'display_login': 'thomaswinckell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thomaswinckell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5302702?'},
#   'repo': {'id': 142294790,
#    'name': 'wintercounter/mhy-config',
#    'url': 'https://api.github.com/repos/wintercounter/mhy-config'},
#   'payload': {'forkee': {'id': 157727407,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNTc3Mjc0MDc=',
#     'name': 'mhy-config',
#     'full_name': 'thomaswinckell/mhy-config',
#     'private': False,
#     'owner': {'login': 'thomaswinckell',
#      'id': 5302702,
#      'node_id': 'MDQ6VXNlcjUzMDI3MDI=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/5302702?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/thomaswinckell',
#      'html_url': 'https://github.com/thomaswinckell',
#      'followers_url': 'https://api.github.com/users/thomaswinckell/followers',
#      'following_url': 'https://api.github.com/users/thomaswinckell/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/thomaswinckell/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/thomaswinckell/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/thomaswinckell/subscriptions',
#      'organizations_url': 'https://api.github.com/users/thomaswinckell/orgs',
#      'repos_url': 'https://api.github.com/users/thomaswinckell/repos',
#      'events_url': 'https://api.github.com/users/thomaswinckell/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/thomaswinckell/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/thomaswinckell/mhy-config',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/thomaswinckell/mhy-config',
#     'forks_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/forks',
#     'keys_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/teams',
#     'hooks_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/hooks',
#     'issue_events_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/events',
#     'assignees_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/tags',
#     'blobs_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/languages',
#     'stargazers_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/stargazers',
#     'contributors_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/contributors',
#     'subscribers_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/subscribers',
#     'subscription_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/subscription',
#     'commits_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/merges',
#     'archive_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/downloads',
#     'issues_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/thomaswinckell/mhy-config/deployments',
#     'created_at': '2018-11-15T14:50:40Z',
#     'updated_at': '2018-11-15T13:30:19Z',
#     'pushed_at': '2018-11-15T13:30:17Z',
#     'git_url': 'git://github.com/thomaswinckell/mhy-config.git',
#     'ssh_url': 'git@github.com:thomaswinckell/mhy-config.git',
#     'clone_url': 'https://github.com/thomaswinckell/mhy-config.git',
#     'svn_url': 'https://github.com/thomaswinckell/mhy-config',
#     'homepage': None,
#     'size': 223,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939500',
#   'type': 'PushEvent',
#   'actor': {'id': 43356121,
#    'login': 'Deji303',
#    'display_login': 'Deji303',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Deji303',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43356121?'},
#   'repo': {'id': 157726657,
#    'name': 'Deji303/speaking-grandma-london-web-121018',
#    'url': 'https://api.github.com/repos/Deji303/speaking-grandma-london-web-121018'},
#   'payload': {'push_id': 3052488082,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '9386aee7630ab3bfc06de6e9b46ee857f489b7fd',
#    'before': '4b5dd77b446fc3a6d6a449ab30d7041532fe3ffe',
#    'commits': [{'sha': '9386aee7630ab3bfc06de6e9b46ee857f489b7fd',
#      'author': {'email': 'ayodeji.okusanya@gmail.com',
#       'name': 'Ayodeji Okusanya'},
#      'message': 'automatically backed up by learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Deji303/speaking-grandma-london-web-121018/commits/9386aee7630ab3bfc06de6e9b46ee857f489b7fd'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939495',
#   'type': 'PushEvent',
#   'actor': {'id': 30787458,
#    'login': 'lmbradley',
#    'display_login': 'lmbradley',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lmbradley',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30787458?'},
#   'repo': {'id': 154869697,
#    'name': 'lmbradley/lmbradley.github.io',
#    'url': 'https://api.github.com/repos/lmbradley/lmbradley.github.io'},
#   'payload': {'push_id': 3052488080,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cd43f78bdc058293c9beeb10e1b4ac37e61e6460',
#    'before': 'd05e3d1a77d89865222ec5c1af96998e4bb5ff5e',
#    'commits': [{'sha': 'cd43f78bdc058293c9beeb10e1b4ac37e61e6460',
#      'author': {'email': 'lmb@asu.edu', 'name': 'LMW'},
#      'message': 'bleh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lmbradley/lmbradley.github.io/commits/cd43f78bdc058293c9beeb10e1b4ac37e61e6460'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939487',
#   'type': 'PushEvent',
#   'actor': {'id': 32097808,
#    'login': 'aaliyahs9023',
#    'display_login': 'aaliyahs9023',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aaliyahs9023',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32097808?'},
#   'repo': {'id': 157561437,
#    'name': 'aaliyahs9023/aaliyahs9023.github.io',
#    'url': 'https://api.github.com/repos/aaliyahs9023/aaliyahs9023.github.io'},
#   'payload': {'push_id': 3052488077,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4e2de617781f793e43d0bc8a45852a63abbad224',
#    'before': 'fa1de8fb79e0c34a8a25ae333ea3b3b353a69122',
#    'commits': [{'sha': '4e2de617781f793e43d0bc8a45852a63abbad224',
#      'author': {'email': 'aaliyahs9023@hstat.org', 'name': 'Aaliyah Sealey'},
#      'message': 'I added a picture of HSTAT',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aaliyahs9023/aaliyahs9023.github.io/commits/4e2de617781f793e43d0bc8a45852a63abbad224'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939490',
#   'type': 'CreateEvent',
#   'actor': {'id': 8694304,
#    'login': 'marbat87',
#    'display_login': 'marbat87',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marbat87',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8694304?'},
#   'repo': {'id': 89576105,
#    'name': 'marbat87/risuscito-android',
#    'url': 'https://api.github.com/repos/marbat87/risuscito-android'},
#   'payload': {'ref': 'v4373',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939483',
#   'type': 'CreateEvent',
#   'actor': {'id': 1838373,
#    'login': 'Kyria',
#    'display_login': 'Kyria',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kyria',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1838373?'},
#   'repo': {'id': 35224879,
#    'name': 'Kyria/LazyBlacksmith',
#    'url': 'https://api.github.com/repos/Kyria/LazyBlacksmith'},
#   'payload': {'ref': 'dev',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'EVE Online Industry app written in python (flask) for backend, html / css / js for frontend',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939473',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 6313872,
#    'login': 'reporobot',
#    'display_login': 'reporobot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reporobot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6313872?'},
#   'repo': {'id': 15783450,
#    'name': 'jlord/patchwork',
#    'url': 'https://api.github.com/repos/jlord/patchwork'},
#   'payload': {'action': 'closed',
#    'number': 26794,
#    'pull_request': {'url': 'https://api.github.com/repos/jlord/patchwork/pulls/26794',
#     'id': 231221070,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjMxMjIxMDcw',
#     'html_url': 'https://github.com/jlord/patchwork/pull/26794',
#     'diff_url': 'https://github.com/jlord/patchwork/pull/26794.diff',
#     'patch_url': 'https://github.com/jlord/patchwork/pull/26794.patch',
#     'issue_url': 'https://api.github.com/repos/jlord/patchwork/issues/26794',
#     'number': 26794,
#     'state': 'closed',
#     'locked': False,
#     'title': 'add krobinson1972',
#     'user': {'login': 'krobinson1972',
#      'id': 3417182,
#      'node_id': 'MDQ6VXNlcjM0MTcxODI=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/3417182?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/krobinson1972',
#      'html_url': 'https://github.com/krobinson1972',
#      'followers_url': 'https://api.github.com/users/krobinson1972/followers',
#      'following_url': 'https://api.github.com/users/krobinson1972/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/krobinson1972/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/krobinson1972/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/krobinson1972/subscriptions',
#      'organizations_url': 'https://api.github.com/users/krobinson1972/orgs',
#      'repos_url': 'https://api.github.com/users/krobinson1972/repos',
#      'events_url': 'https://api.github.com/users/krobinson1972/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/krobinson1972/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2018-11-15T14:50:36Z',
#     'updated_at': '2018-11-15T14:50:40Z',
#     'closed_at': '2018-11-15T14:50:40Z',
#     'merged_at': '2018-11-15T14:50:39Z',
#     'merge_commit_sha': 'fec207366c367e4a2f74b4f37f799809478c3e04',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/jlord/patchwork/pulls/26794/commits',
#     'review_comments_url': 'https://api.github.com/repos/jlord/patchwork/pulls/26794/comments',
#     'review_comment_url': 'https://api.github.com/repos/jlord/patchwork/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jlord/patchwork/issues/26794/comments',
#     'statuses_url': 'https://api.github.com/repos/jlord/patchwork/statuses/d42583c234bdf6939b813b1ef320efde75a16c8a',
#     'head': {'label': 'krobinson1972:add-krobinson1972',
#      'ref': 'add-krobinson1972',
#      'sha': 'd42583c234bdf6939b813b1ef320efde75a16c8a',
#      'user': {'login': 'krobinson1972',
#       'id': 3417182,
#       'node_id': 'MDQ6VXNlcjM0MTcxODI=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/3417182?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/krobinson1972',
#       'html_url': 'https://github.com/krobinson1972',
#       'followers_url': 'https://api.github.com/users/krobinson1972/followers',
#       'following_url': 'https://api.github.com/users/krobinson1972/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/krobinson1972/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/krobinson1972/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/krobinson1972/subscriptions',
#       'organizations_url': 'https://api.github.com/users/krobinson1972/orgs',
#       'repos_url': 'https://api.github.com/users/krobinson1972/repos',
#       'events_url': 'https://api.github.com/users/krobinson1972/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/krobinson1972/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 157724662,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTc3MjQ2NjI=',
#       'name': 'patchwork',
#       'full_name': 'krobinson1972/patchwork',
#       'private': False,
#       'owner': {'login': 'krobinson1972',
#        'id': 3417182,
#        'node_id': 'MDQ6VXNlcjM0MTcxODI=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/3417182?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/krobinson1972',
#        'html_url': 'https://github.com/krobinson1972',
#        'followers_url': 'https://api.github.com/users/krobinson1972/followers',
#        'following_url': 'https://api.github.com/users/krobinson1972/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/krobinson1972/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/krobinson1972/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/krobinson1972/subscriptions',
#        'organizations_url': 'https://api.github.com/users/krobinson1972/orgs',
#        'repos_url': 'https://api.github.com/users/krobinson1972/repos',
#        'events_url': 'https://api.github.com/users/krobinson1972/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/krobinson1972/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/krobinson1972/patchwork',
#       'description': 'All the Git-it Workshop completers! ',
#       'fork': True,
#       'url': 'https://api.github.com/repos/krobinson1972/patchwork',
#       'forks_url': 'https://api.github.com/repos/krobinson1972/patchwork/forks',
#       'keys_url': 'https://api.github.com/repos/krobinson1972/patchwork/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/krobinson1972/patchwork/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/krobinson1972/patchwork/teams',
#       'hooks_url': 'https://api.github.com/repos/krobinson1972/patchwork/hooks',
#       'issue_events_url': 'https://api.github.com/repos/krobinson1972/patchwork/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/krobinson1972/patchwork/events',
#       'assignees_url': 'https://api.github.com/repos/krobinson1972/patchwork/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/krobinson1972/patchwork/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/krobinson1972/patchwork/tags',
#       'blobs_url': 'https://api.github.com/repos/krobinson1972/patchwork/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/krobinson1972/patchwork/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/krobinson1972/patchwork/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/krobinson1972/patchwork/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/krobinson1972/patchwork/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/krobinson1972/patchwork/languages',
#       'stargazers_url': 'https://api.github.com/repos/krobinson1972/patchwork/stargazers',
#       'contributors_url': 'https://api.github.com/repos/krobinson1972/patchwork/contributors',
#       'subscribers_url': 'https://api.github.com/repos/krobinson1972/patchwork/subscribers',
#       'subscription_url': 'https://api.github.com/repos/krobinson1972/patchwork/subscription',
#       'commits_url': 'https://api.github.com/repos/krobinson1972/patchwork/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/krobinson1972/patchwork/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/krobinson1972/patchwork/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/krobinson1972/patchwork/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/krobinson1972/patchwork/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/krobinson1972/patchwork/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/krobinson1972/patchwork/merges',
#       'archive_url': 'https://api.github.com/repos/krobinson1972/patchwork/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/krobinson1972/patchwork/downloads',
#       'issues_url': 'https://api.github.com/repos/krobinson1972/patchwork/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/krobinson1972/patchwork/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/krobinson1972/patchwork/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/krobinson1972/patchwork/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/krobinson1972/patchwork/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/krobinson1972/patchwork/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/krobinson1972/patchwork/deployments',
#       'created_at': '2018-11-15T14:31:00Z',
#       'updated_at': '2018-11-15T14:31:12Z',
#       'pushed_at': '2018-11-15T14:47:18Z',
#       'git_url': 'git://github.com/krobinson1972/patchwork.git',
#       'ssh_url': 'git@github.com:krobinson1972/patchwork.git',
#       'clone_url': 'https://github.com/krobinson1972/patchwork.git',
#       'svn_url': 'https://github.com/krobinson1972/patchwork',
#       'homepage': 'http://jlord.github.io/patchwork',
#       'size': 120445,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'gh-pages'}},
#     'base': {'label': 'jlord:gh-pages',
#      'ref': 'gh-pages',
#      'sha': 'fab21e59d5c8f355aa1aa582b8e9c4e9166143e6',
#      'user': {'login': 'jlord',
#       'id': 1305617,
#       'node_id': 'MDQ6VXNlcjEzMDU2MTc=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/1305617?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jlord',
#       'html_url': 'https://github.com/jlord',
#       'followers_url': 'https://api.github.com/users/jlord/followers',
#       'following_url': 'https://api.github.com/users/jlord/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jlord/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jlord/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jlord/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jlord/orgs',
#       'repos_url': 'https://api.github.com/users/jlord/repos',
#       'events_url': 'https://api.github.com/users/jlord/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jlord/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 15783450,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTc4MzQ1MA==',
#       'name': 'patchwork',
#       'full_name': 'jlord/patchwork',
#       'private': False,
#       'owner': {'login': 'jlord',
#        'id': 1305617,
#        'node_id': 'MDQ6VXNlcjEzMDU2MTc=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/1305617?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jlord',
#        'html_url': 'https://github.com/jlord',
#        'followers_url': 'https://api.github.com/users/jlord/followers',
#        'following_url': 'https://api.github.com/users/jlord/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jlord/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jlord/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jlord/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jlord/orgs',
#        'repos_url': 'https://api.github.com/users/jlord/repos',
#        'events_url': 'https://api.github.com/users/jlord/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jlord/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jlord/patchwork',
#       'description': 'All the Git-it Workshop completers! ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/jlord/patchwork',
#       'forks_url': 'https://api.github.com/repos/jlord/patchwork/forks',
#       'keys_url': 'https://api.github.com/repos/jlord/patchwork/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jlord/patchwork/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jlord/patchwork/teams',
#       'hooks_url': 'https://api.github.com/repos/jlord/patchwork/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jlord/patchwork/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jlord/patchwork/events',
#       'assignees_url': 'https://api.github.com/repos/jlord/patchwork/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jlord/patchwork/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jlord/patchwork/tags',
#       'blobs_url': 'https://api.github.com/repos/jlord/patchwork/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jlord/patchwork/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jlord/patchwork/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jlord/patchwork/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jlord/patchwork/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jlord/patchwork/languages',
#       'stargazers_url': 'https://api.github.com/repos/jlord/patchwork/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jlord/patchwork/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jlord/patchwork/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jlord/patchwork/subscription',
#       'commits_url': 'https://api.github.com/repos/jlord/patchwork/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jlord/patchwork/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jlord/patchwork/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jlord/patchwork/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jlord/patchwork/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jlord/patchwork/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jlord/patchwork/merges',
#       'archive_url': 'https://api.github.com/repos/jlord/patchwork/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jlord/patchwork/downloads',
#       'issues_url': 'https://api.github.com/repos/jlord/patchwork/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jlord/patchwork/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jlord/patchwork/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jlord/patchwork/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jlord/patchwork/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jlord/patchwork/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jlord/patchwork/deployments',
#       'created_at': '2014-01-10T00:00:11Z',
#       'updated_at': '2018-11-15T12:04:10Z',
#       'pushed_at': '2018-11-15T14:50:39Z',
#       'git_url': 'git://github.com/jlord/patchwork.git',
#       'ssh_url': 'git@github.com:jlord/patchwork.git',
#       'clone_url': 'https://github.com/jlord/patchwork.git',
#       'svn_url': 'https://github.com/jlord/patchwork',
#       'homepage': 'http://jlord.github.io/patchwork',
#       'size': 120445,
#       'stargazers_count': 793,
#       'watchers_count': 793,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 21877,
#       'mirror_url': None,
#       'archived': False,
#       'open_issues_count': 511,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 21877,
#       'open_issues': 511,
#       'watchers': 793,
#       'default_branch': 'gh-pages'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jlord/patchwork/pulls/26794'},
#      'html': {'href': 'https://github.com/jlord/patchwork/pull/26794'},
#      'issue': {'href': 'https://api.github.com/repos/jlord/patchwork/issues/26794'},
#      'comments': {'href': 'https://api.github.com/repos/jlord/patchwork/issues/26794/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jlord/patchwork/pulls/26794/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jlord/patchwork/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jlord/patchwork/pulls/26794/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jlord/patchwork/statuses/d42583c234bdf6939b813b1ef320efde75a16c8a'}},
#     'author_association': 'NONE',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'reporobot',
#      'id': 6313872,
#      'node_id': 'MDQ6VXNlcjYzMTM4NzI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6313872?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/reporobot',
#      'html_url': 'https://github.com/reporobot',
#      'followers_url': 'https://api.github.com/users/reporobot/followers',
#      'following_url': 'https://api.github.com/users/reporobot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/reporobot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/reporobot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/reporobot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/reporobot/orgs',
#      'repos_url': 'https://api.github.com/users/reporobot/repos',
#      'events_url': 'https://api.github.com/users/reporobot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/reporobot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939467',
#   'type': 'PushEvent',
#   'actor': {'id': 19337229,
#    'login': 'iamdevlinph',
#    'display_login': 'iamdevlinph',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iamdevlinph',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19337229?'},
#   'repo': {'id': 119498926,
#    'name': 'codesandcoffees/react-pkg',
#    'url': 'https://api.github.com/repos/codesandcoffees/react-pkg'},
#   'payload': {'push_id': 3052488074,
#    'size': 5,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '44aacbc04e9bade9526f447c37d084a67c1d6bc8',
#    'before': 'b8056c0dc0e31b4c0cb1d016b5483918132e623c',
#    'commits': [{'sha': '9c973de6cab0137e183ae540d30c79156ae4f23d',
#      'author': {'email': 'greenkeeper[bot]@users.noreply.github.com',
#       'name': 'greenkeeper[bot]'},
#      'message': 'fix(package): update react to version 16.6.1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codesandcoffees/react-pkg/commits/9c973de6cab0137e183ae540d30c79156ae4f23d'},
#     {'sha': '9b57a2c9b8161a2d314e9eb188518a4614f908b1',
#      'author': {'email': 'greenkeeper[bot]@users.noreply.github.com',
#       'name': 'greenkeeper[bot]'},
#      'message': 'fix(package): update react-dom to version 16.6.1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codesandcoffees/react-pkg/commits/9b57a2c9b8161a2d314e9eb188518a4614f908b1'},
#     {'sha': '3287ffae6dd88f192e4e72086622388aae15a346',
#      'author': {'email': 'iamdevlinph@gmail.com', 'name': 'Devlin Pajaron'},
#      'message': "Merge branch 'master' into greenkeeper/monorepo.react-16.6.1",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codesandcoffees/react-pkg/commits/3287ffae6dd88f192e4e72086622388aae15a346'},
#     {'sha': 'c51075d02bcd139a6f1f782928ec50a245be8e02',
#      'author': {'email': 'iamdevlinph@gmail.com', 'name': 'Devlin Pajaron'},
#      'message': "Merge branch 'master' into greenkeeper/monorepo.react-16.6.1",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codesandcoffees/react-pkg/commits/c51075d02bcd139a6f1f782928ec50a245be8e02'},
#     {'sha': '44aacbc04e9bade9526f447c37d084a67c1d6bc8',
#      'author': {'email': 'iamdevlinph@gmail.com', 'name': 'Devlin Pajaron'},
#      'message': 'Merge pull request #25 from codesandcoffees/greenkeeper/monorepo.react-16.6.1\n\nUpdate react to the latest version 🚀',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/codesandcoffees/react-pkg/commits/44aacbc04e9bade9526f447c37d084a67c1d6bc8'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z',
#   'org': {'id': 30825136,
#    'login': 'codesandcoffees',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codesandcoffees',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30825136?'}},
#  {'id': '8595939472',
#   'type': 'CreateEvent',
#   'actor': {'id': 42797204,
#    'login': 'alexandrurizea86',
#    'display_login': 'alexandrurizea86',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexandrurizea86',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42797204?'},
#   'repo': {'id': 157727406,
#    'name': 'alexandrurizea86/probe',
#    'url': 'https://api.github.com/repos/alexandrurizea86/probe'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Probele frontend',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939465',
#   'type': 'PushEvent',
#   'actor': {'id': 11923555,
#    'login': 'xucore',
#    'display_login': 'xucore',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xucore',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11923555?'},
#   'repo': {'id': 157400428,
#    'name': 'xucore/system-analyst',
#    'url': 'https://api.github.com/repos/xucore/system-analyst'},
#   'payload': {'push_id': 3052488062,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '11261294a20435b536aa320519f9b43d16b337d1',
#    'before': '3ce417c7ec20421464ffa333ccb8dd8b70685f9f',
#    'commits': [{'sha': '11261294a20435b536aa320519f9b43d16b337d1',
#      'author': {'email': '286942689@qq.com', 'name': 'xucore'},
#      'message': 'Delete system-analyst.idx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xucore/system-analyst/commits/11261294a20435b536aa320519f9b43d16b337d1'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939461',
#   'type': 'PushEvent',
#   'actor': {'id': 12952936,
#    'login': 'Cedr71',
#    'display_login': 'Cedr71',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cedr71',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12952936?'},
#   'repo': {'id': 114462357,
#    'name': 'Cedr71/traduction',
#    'url': 'https://api.github.com/repos/Cedr71/traduction'},
#   'payload': {'push_id': 3052488070,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c1430a0acbdc4c02493c9793e2167433fb0dd1d4',
#    'before': '611fb83de1cd5dc57a74520fa64302a99e6c338e',
#    'commits': [{'sha': 'c1430a0acbdc4c02493c9793e2167433fb0dd1d4',
#      'author': {'email': 'cedricforner@msn.com', 'name': 'Cedr71'},
#      'message': '15/11',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Cedr71/traduction/commits/c1430a0acbdc4c02493c9793e2167433fb0dd1d4'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939462',
#   'type': 'PushEvent',
#   'actor': {'id': 6806258,
#    'login': 'mjdescy',
#    'display_login': 'mjdescy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mjdescy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6806258?'},
#   'repo': {'id': 116209907,
#    'name': 'mjdescy/mjdescy.github.io',
#    'url': 'https://api.github.com/repos/mjdescy/mjdescy.github.io'},
#   'payload': {'push_id': 3052488064,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '60c26b03cf8814ef08b0cede6567b944371bbf9d',
#    'before': '70e045d89e45db5a5a32e507b769d695759a5504',
#    'commits': [{'sha': '60c26b03cf8814ef08b0cede6567b944371bbf9d',
#      'author': {'email': 'mjdescy@users.noreply.github.com',
#       'name': 'Michael Descy'},
#      'message': 'Mirroring from Micro.blog.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mjdescy/mjdescy.github.io/commits/60c26b03cf8814ef08b0cede6567b944371bbf9d'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939459',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 150406791,
#    'name': 'newstools/2018-weekly-expose',
#    'url': 'https://api.github.com/repos/newstools/2018-weekly-expose'},
#   'payload': {'push_id': 3052488063,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5b502cd78ac390f04e884ca39d88a68ad6f71801',
#    'before': '420c39ea9e7ca214eb7c4fcba6fd10ef5f4b876c',
#    'commits': [{'sha': '5b502cd78ac390f04e884ca39d88a68ad6f71801',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [weeklyxpose.co.za/2018/11/15/top-acts-usher-holiday-season-festive-lights-switch/]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2018-weekly-expose/commits/5b502cd78ac390f04e884ca39d88a68ad6f71801'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939463',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 8694304,
#    'login': 'marbat87',
#    'display_login': 'marbat87',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marbat87',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8694304?'},
#   'repo': {'id': 89576105,
#    'name': 'marbat87/risuscito-android',
#    'url': 'https://api.github.com/repos/marbat87/risuscito-android'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/marbat87/risuscito-android/releases/14023060',
#     'assets_url': 'https://api.github.com/repos/marbat87/risuscito-android/releases/14023060/assets',
#     'upload_url': 'https://uploads.github.com/repos/marbat87/risuscito-android/releases/14023060/assets{?name,label}',
#     'html_url': 'https://github.com/marbat87/risuscito-android/releases/tag/v4373',
#     'id': 14023060,
#     'node_id': 'MDc6UmVsZWFzZTE0MDIzMDYw',
#     'tag_name': 'v4373',
#     'target_commitish': 'development',
#     'name': 'v4.3.2-beta73',
#     'draft': False,
#     'author': {'login': 'marbat87',
#      'id': 8694304,
#      'node_id': 'MDQ6VXNlcjg2OTQzMDQ=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/8694304?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/marbat87',
#      'html_url': 'https://github.com/marbat87',
#      'followers_url': 'https://api.github.com/users/marbat87/followers',
#      'following_url': 'https://api.github.com/users/marbat87/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/marbat87/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/marbat87/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/marbat87/subscriptions',
#      'organizations_url': 'https://api.github.com/users/marbat87/orgs',
#      'repos_url': 'https://api.github.com/users/marbat87/repos',
#      'events_url': 'https://api.github.com/users/marbat87/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/marbat87/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'prerelease': True,
#     'created_at': '2018-11-15T14:28:44Z',
#     'published_at': '2018-11-15T14:50:40Z',
#     'assets': [{'url': 'https://api.github.com/repos/marbat87/risuscito-android/releases/assets/9708170',
#       'id': 9708170,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDk3MDgxNzA=',
#       'name': 'mapping_4373.txt',
#       'label': None,
#       'uploader': {'login': 'marbat87',
#        'id': 8694304,
#        'node_id': 'MDQ6VXNlcjg2OTQzMDQ=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/8694304?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/marbat87',
#        'html_url': 'https://github.com/marbat87',
#        'followers_url': 'https://api.github.com/users/marbat87/followers',
#        'following_url': 'https://api.github.com/users/marbat87/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/marbat87/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/marbat87/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/marbat87/subscriptions',
#        'organizations_url': 'https://api.github.com/users/marbat87/orgs',
#        'repos_url': 'https://api.github.com/users/marbat87/repos',
#        'events_url': 'https://api.github.com/users/marbat87/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/marbat87/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'text/plain',
#       'state': 'uploaded',
#       'size': 11085235,
#       'download_count': 0,
#       'created_at': '2018-11-15T14:50:10Z',
#       'updated_at': '2018-11-15T14:50:29Z',
#       'browser_download_url': 'https://github.com/marbat87/risuscito-android/releases/download/v4373/mapping_4373.txt'},
#      {'url': 'https://api.github.com/repos/marbat87/risuscito-android/releases/assets/9708156',
#       'id': 9708156,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDk3MDgxNTY=',
#       'name': 'risuscito_4373.apk',
#       'label': None,
#       'uploader': {'login': 'marbat87',
#        'id': 8694304,
#        'node_id': 'MDQ6VXNlcjg2OTQzMDQ=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/8694304?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/marbat87',
#        'html_url': 'https://github.com/marbat87',
#        'followers_url': 'https://api.github.com/users/marbat87/followers',
#        'following_url': 'https://api.github.com/users/marbat87/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/marbat87/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/marbat87/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/marbat87/subscriptions',
#        'organizations_url': 'https://api.github.com/users/marbat87/orgs',
#        'repos_url': 'https://api.github.com/users/marbat87/repos',
#        'events_url': 'https://api.github.com/users/marbat87/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/marbat87/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 8657807,
#       'download_count': 0,
#       'created_at': '2018-11-15T14:49:49Z',
#       'updated_at': '2018-11-15T14:50:03Z',
#       'browser_download_url': 'https://github.com/marbat87/risuscito-android/releases/download/v4373/risuscito_4373.apk'}],
#     'tarball_url': 'https://api.github.com/repos/marbat87/risuscito-android/tarball/v4373',
#     'zipball_url': 'https://api.github.com/repos/marbat87/risuscito-android/zipball/v4373',
#     'body': 'Correzione canti\r\nsostituzione label dialogs'}},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939441',
#   'type': 'PushEvent',
#   'actor': {'id': 1165305,
#    'login': 'turbobrian',
#    'display_login': 'turbobrian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/turbobrian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1165305?'},
#   'repo': {'id': 53109381,
#    'name': 'turbobrian/hackery',
#    'url': 'https://api.github.com/repos/turbobrian/hackery'},
#   'payload': {'push_id': 3052488055,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '54bf96d2f5d2f8dfc332abd190f2013bf1f0ec91',
#    'before': 'd3beaa787146576a30f5bd7771a69ade575ca11b',
#    'commits': [{'sha': '54bf96d2f5d2f8dfc332abd190f2013bf1f0ec91',
#      'author': {'email': 'github@notanonymo.us', 'name': 'Brian'},
#      'message': 'commit+1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/turbobrian/hackery/commits/54bf96d2f5d2f8dfc332abd190f2013bf1f0ec91'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939444',
#   'type': 'PushEvent',
#   'actor': {'id': 42836813,
#    'login': 'bluemarlin1134',
#    'display_login': 'bluemarlin1134',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bluemarlin1134',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42836813?'},
#   'repo': {'id': 157726444,
#    'name': 'bluemarlin1134/TechProblems',
#    'url': 'https://api.github.com/repos/bluemarlin1134/TechProblems'},
#   'payload': {'push_id': 3052488056,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '110fd9bef070ace5be737eb63f05ab53ec14a761',
#    'before': '059edaa9b471ff81a8f5314dcb28910b546c1e53',
#    'commits': [{'sha': '110fd9bef070ace5be737eb63f05ab53ec14a761',
#      'author': {'email': '42836813+bluemarlin1134@users.noreply.github.com',
#       'name': 'bluemarlin1134'},
#      'message': 'Update login.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bluemarlin1134/TechProblems/commits/110fd9bef070ace5be737eb63f05ab53ec14a761'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939442',
#   'type': 'PushEvent',
#   'actor': {'id': 25231582,
#    'login': 'dev637',
#    'display_login': 'dev637',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dev637',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25231582?'},
#   'repo': {'id': 157319781,
#    'name': 'dev637/fullstacktodoapp',
#    'url': 'https://api.github.com/repos/dev637/fullstacktodoapp'},
#   'payload': {'push_id': 3052488047,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '16768e70351f2d82c32ef0e7cce4326cb21d59c7',
#    'before': 'dc28d148a9d5c9b568f40065715de331fc70aceb',
#    'commits': [{'sha': '16768e70351f2d82c32ef0e7cce4326cb21d59c7',
#      'author': {'email': 'devang713@gmail.com', 'name': 'dev637'},
#      'message': 'Add get and delete UserTodo functions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dev637/fullstacktodoapp/commits/16768e70351f2d82c32ef0e7cce4326cb21d59c7'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z'},
#  {'id': '8595939443',
#   'type': 'PushEvent',
#   'actor': {'id': 22226823,
#    'login': 'securisec',
#    'display_login': 'securisec',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/securisec',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22226823?'},
#   'repo': {'id': 156791386,
#    'name': 'securisec/securisec.github.io',
# ...
#       'statuses_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/languages',
#       'stargazers_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/subscription',
#       'commits_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/merges',
#       'archive_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/downloads',
#       'issues_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/joshuawaheed/parliament.uk-pugin/deployments',
#       'created_at': '2017-11-14T11:23:48Z',
#       'updated_at': '2018-11-14T15:23:59Z',
#       'pushed_at': '2018-11-15T14:50:09Z',
#       'git_url': 'git://github.com/joshuawaheed/parliament.uk-pugin.git',
#       'ssh_url': 'git@github.com:joshuawaheed/parliament.uk-pugin.git',
#       'clone_url': 'https://github.com/joshuawaheed/parliament.uk-pugin.git',
#       'svn_url': 'https://github.com/joshuawaheed/parliament.uk-pugin',
#       'homepage': 'https://parliament-uk-pugin.herokuapp.com',
#       'size': 9040,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ukparliament:master',
#      'ref': 'master',
#      'sha': 'd5c6371eecff276575ce0a73172b157fb6d6ba60',
#      'user': {'login': 'ukparliament',
#       'id': 7130076,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcxMzAwNzY=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/7130076?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ukparliament',
#       'html_url': 'https://github.com/ukparliament',
#       'followers_url': 'https://api.github.com/users/ukparliament/followers',
#       'following_url': 'https://api.github.com/users/ukparliament/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ukparliament/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ukparliament/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ukparliament/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ukparliament/orgs',
#       'repos_url': 'https://api.github.com/users/ukparliament/repos',
#       'events_url': 'https://api.github.com/users/ukparliament/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ukparliament/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 80195012,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4MDE5NTAxMg==',
#       'name': 'parliament.uk-pugin',
#       'full_name': 'ukparliament/parliament.uk-pugin',
#       'private': False,
#       'owner': {'login': 'ukparliament',
#        'id': 7130076,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcxMzAwNzY=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/7130076?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ukparliament',
#        'html_url': 'https://github.com/ukparliament',
#        'followers_url': 'https://api.github.com/users/ukparliament/followers',
#        'following_url': 'https://api.github.com/users/ukparliament/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ukparliament/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ukparliament/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ukparliament/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ukparliament/orgs',
#        'repos_url': 'https://api.github.com/users/ukparliament/repos',
#        'events_url': 'https://api.github.com/users/ukparliament/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ukparliament/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ukparliament/parliament.uk-pugin',
#       'description': 'UK Parliament brand',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin',
#       'forks_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/forks',
#       'keys_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/teams',
#       'hooks_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/events',
#       'assignees_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/tags',
#       'blobs_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/languages',
#       'stargazers_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/subscription',
#       'commits_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/merges',
#       'archive_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/downloads',
#       'issues_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/deployments',
#       'created_at': '2017-01-27T09:28:24Z',
#       'updated_at': '2018-11-09T09:28:54Z',
#       'pushed_at': '2018-11-09T09:30:38Z',
#       'git_url': 'git://github.com/ukparliament/parliament.uk-pugin.git',
#       'ssh_url': 'git@github.com:ukparliament/parliament.uk-pugin.git',
#       'clone_url': 'https://github.com/ukparliament/parliament.uk-pugin.git',
#       'svn_url': 'https://github.com/ukparliament/parliament.uk-pugin',
#       'homepage': 'https://parliament-uk-pugin.herokuapp.com/',
#       'size': 8582,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 12,
#       'mirror_url': None,
#       'archived': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 12,
#       'open_issues': 1,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/pulls/541'},
#      'html': {'href': 'https://github.com/ukparliament/parliament.uk-pugin/pull/541'},
#      'issue': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/issues/541'},
#      'comments': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/issues/541/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/pulls/541/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/pulls/541/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ukparliament/parliament.uk-pugin/statuses/03f8983c958e78a26e01dbba86c7daf408f4d597'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 88,
#     'deletions': 88,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2018-11-15T14:50:40Z',
#   'org': {'id': 7130076,
#    'login': 'ukparliament',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ukparliament',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7130076?'}},
#  {'id': '8595939417',
#   'type': 'PushEvent',
#   'actor': {'id': 8293404,
#    'login': 'ronguest',
#    'display_login': 'ronguest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ronguest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8293404?'},
#   'repo': {'id': 118158255,
#    'name': 'ronguest/ronguest.github.io',
#    'url': 'https://api.github.com/repos/ronguest/ronguest.github.io'},
#   'payload': {'push_id': 3052488038,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '19f11c90bd2b76dfbc6e77fd81518049f86e1939',
#    'before': '8e34740518421f417864de5f1661c39a59f94b56',
#    'commits': [{'sha': '19f11c90bd2b76dfbc6e77fd81518049f86e1939',
#      'author': {'email': 'ronguest@users.noreply.github.com',
#       'name': 'Ron Guest'},
#      'message': 'Mirroring from Micro.blog.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ronguest/ronguest.github.io/commits/19f11c90bd2b76dfbc6e77fd81518049f86e1939'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:39Z'},
#  {'id': '8595939409',
#   'type': 'CreateEvent',
#   'actor': {'id': 1341245,
#    'login': 'asfgit',
#    'display_login': 'asfgit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asfgit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1341245?'},
#   'repo': {'id': 107435906,
#    'name': 'apache/sling-org-apache-sling-testing-jcr-mock',
#    'url': 'https://api.github.com/repos/apache/sling-org-apache-sling-testing-jcr-mock'},
#   'payload': {'ref': 'org.apache.sling.testing.jcr-mock-1.4.2',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Apache Sling Testing JCR Mock',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:39Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '8595939408',
#   'type': 'CreateEvent',
#   'actor': {'id': 968949,
#    'login': 'bgeuken',
#    'display_login': 'bgeuken',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bgeuken',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/968949?'},
#   'repo': {'id': 10003040,
#    'name': 'bgeuken/open-build-service',
#    'url': 'https://api.github.com/repos/bgeuken/open-build-service'},
#   'payload': {'ref': 'missing_reviews',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A generic system to build and distribute packages from sources in an automatic, consistent and reproducible way. Release your software for a wide range of operating systems and hardware architectures.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-11-15T14:50:39Z'},
#  {'id': '8595939404',
#   'type': 'PushEvent',
#   'actor': {'id': 29988141,
#    'login': 'liuxin21',
#    'display_login': 'liuxin21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liuxin21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29988141?'},
#   'repo': {'id': 96575569,
#    'name': 'liuxin21/liuxin21.github.io',
#    'url': 'https://api.github.com/repos/liuxin21/liuxin21.github.io'},
#   'payload': {'push_id': 3052488031,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f3dc5ff4a2909bb41dd038a66825f898cce6a494',
#    'before': '1faf159d776b87c66b9ef3906ebb9dc186ed79ce',
#    'commits': [{'sha': 'f3dc5ff4a2909bb41dd038a66825f898cce6a494',
#      'author': {'email': 'x399liu@edu.uwaterloo.ca', 'name': 'liuxin21'},
#      'message': 'note',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/liuxin21/liuxin21.github.io/commits/f3dc5ff4a2909bb41dd038a66825f898cce6a494'}]},
#   'public': True,
#   'created_at': '2018-11-15T14:50:39Z'}]

# %%
s=requests.Session()
s.verify=False

# Function to get the vCenter server session
def get_vc_session(vcip,username,password):
         s.post('https://'+vcip+'/rest/com/vmware/cis/session',auth=(username,password))
         return s

# Function to get all the VMs from vCenter inventory
def get_vms(vcip):
        vms=s.get('https://'+vcip+'/rest/vcenter/vm')
        return vms

"""#Function to power on particular VM
def poweron_vm(vmmoid,vcip):
        s.post('https://'+vcip+'/rest/vcenter/vm/'+vmmoid+'/power/start')

# Function to power off particular VM
def poweroff_vm(vmmoid,vcip):
        s.post('https://'+vcip+'/rest/vcenter/vm/'+vmmoid+'/power/stop')
        
"""
